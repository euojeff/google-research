# %%
import tensorflow as tf
# Out:
# 2022-11-14 01:37:02.465381: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !python script_download_data.py electricity download
# Out:
# 2022-11-14 01:49:01.063582: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# #### Running download script ###
# Resetting data folder...
# Getting electricity data...
# Pulling data from https://archive.ics.uci.edu/ml/machine-learning-databases/00321/LD2011_2014.txt.zip to data/data/electricity/LD2011_2014.txt.zip
# 100% [..................................................] 261335609 / 261335609done / 261335609
# Unzipping file: data/data/electricity/LD2011_2014.txt.zip
# Done.
# Aggregating to hourly data
# Processing MT_001
# Processing MT_002
# Processing MT_003
# Processing MT_004
# Processing MT_005
# Processing MT_006
# Processing MT_007
# Processing MT_008
# Processing MT_009
# Processing MT_010
# ...
